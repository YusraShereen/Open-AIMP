# %% [markdown]
# # **TASK # 1**

# %% [markdown]
# # Using Linear Regression to predict marks on the basis of study hours

# %% [markdown]
# # Author: Yusra Shereen

# %% [markdown]
# In this task student marks are predicted using linear regression on the basis of study hours.

# %% [markdown]
# ### **Importing Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %% [markdown]
# ### **Reading Data**

# %%
url = 'https://raw.githubusercontent.com/AdiPersonalWorks/Random/master/student_scores%20-%20student_scores.csv'
data = pd.read_csv(url)
data.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %% [markdown]
# ### **Exploring Data**

# %%
data.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %% [markdown]
# ### **Data Cleaning (Checking for null values)**

# %%
data.isna().sum()
# Out:
# Hours     0
# Scores    0
# dtype: int64

# %% [markdown]
# ### **Preparing Data**

# %%
x = data['Hours'].values.reshape(-1,1)
y = data['Scores'].values.reshape(-1,1)

# %% [markdown]
# ### **Visualizing Data**

# %%
data.plot(x = 'Hours',y = 'Scores',kind = 'scatter')
plt.title('Study Hours Vs Students Result')
plt.show()

# %% [markdown]
# ### **Train Test Split**

# %%
# Splitting data into train and test
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.15, random_state=0)

# %% [markdown]
# ### **Training Linear Regression Model**

# %%
LR = LinearRegression()
LR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_test
# Out:
# array([[20],
#        [27],
#        [69],
#        [30]])

# %% [markdown]
# ### **Comparing Actual Vs Predicted**

# %%
y_pred = LR.predict(x_test)
df = pd.DataFrame({'Actual': list(y_test), 
                   'Predicted': list(y_pred)})  
df
# Out:
#   Actual             Predicted
# 0   [20]   [16.92714814644114]
# 1   [27]   [33.78826949962361]
# 2   [69]   [75.44515754866265]
# 3   [30]  [26.845454824783772]

# %% [markdown]
# ### **Visualizing Regressor on training model**

# %%
plt.scatter(x_train,y_train, color = 'red')
plt.plot(x_train, LR.predict(x_train),color = 'blue')
plt.title('Study hours Vs Percentage')
plt.xlabel('Hours')
plt.ylabel('Scores')
plt.show()

# %% [markdown]
# ### **Visualizing Linear regressor fit on test data**

# %%
plt.scatter(x_test,y_test, color = 'green')
plt.plot(x_test, y_pred,color = 'blue')
plt.title('Study hours Vs Percentage(on Test Data)')
plt.xlabel('Hours')
plt.ylabel('Scores')
plt.show()

# %% [markdown]
# ### **Evaluating Regressor Model**

# %%
print('Mean Abs error: ',metrics.mean_absolute_error(y_test,y_pred))
print('Mean Squared error: ',metrics.mean_squared_error(y_test,y_pred))
print('Root Mean Square error: ',np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# Mean Abs error:  4.865206019265337
# Mean Squared error:  26.753558100750855
# Root Mean Square error:  5.1723841795395336

# %% [markdown]
# ### **Predicting on different Data**

# %% [markdown]
# What will be predicted score if a student studies for 9.25 hrs/ day?

# %%
hours = 9.25
h_pred = LR.predict(np.array(hours).reshape(-1,1))
print(h_pred)
# Out:
# [[93.7940249]]
